# %%
import os

print(os.environ['PAFY_BACKEND'])
#  = internal

import pafy

url = "https://youtu.be/CgDqB09KQDU"
video = pafy.new(url)
print(video.length)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\gupta\OneDrive\Stuff\Projects\Ashutosh Modi - Exploration Labs\Sign Language Translation - Material\Scraping 2\Videos_with_duration.ipynb Cell 1' in <module>
#       <a href='vscode-notebook-cell:/c%3A/Users/gupta/OneDrive/Stuff/Projects/Ashutosh%20Modi%20-%20Exploration%20Labs/Sign%20Language%20Translation%20-%20Material/Scraping%202/Videos_with_duration.ipynb#ch0000000?line=0'>1</a> import os
# ----> <a href='vscode-notebook-cell:/c%3A/Users/gupta/OneDrive/Stuff/Projects/Ashutosh%20Modi%20-%20Exploration%20Labs/Sign%20Language%20Translation%20-%20Material/Scraping%202/Videos_with_duration.ipynb#ch0000000?line=2'>3</a> print(os.environ['PAFY_BACKEND'])
# ...

# %%
import pandas as pd
df = pd.read_csv("Videos.csv")
df.drop(df[df['Word']=="Private video"].index,inplace=True)
df
# Out:
#                        Word                                         Link  \
# 0                       tea  https://www.youtube.com/watch?v=l7GQ-fR-DsA
# 1                     teach  https://www.youtube.com/watch?v=Brqv7-rpdTQ
# 2                   teacher  https://www.youtube.com/watch?v=Qy_q0sAucuw
# 3             team (sign 1)  https://www.youtube.com/watch?v=kqc7eglNJvE
# 4             team (sign 2)  https://www.youtube.com/watch?v=0REGTy6eqSc
# ...                     ...                                          ...
# 9487         1,000 thousand  https://www.youtube.com/watch?v=RGDTXsCvZBQ
# 9488     2,000 two thousand  https://www.youtube.com/watch?v=b_TvDsf97GY
# 9489    10,000 ten thousand  https://www.youtube.com/watch?v=4tKpSwmWzRc
# 9490      1,00,000 one lakh  https://www.youtube.com/watch?v=sw0z81Ri4ps
# 9491  1,00,00,000 one crore  https://www.youtube.com/watch?v=6Xyl6CNQ_f4
#
#                ID
# 0     l7GQ-fR-DsA
# 1     Brqv7-rpdTQ
# 2     Qy_q0sAucuw
# ...

# %%
import numpy as np
dur_array = []
duration = np.array(dur_array)
for i in range(len(df)):
    url = df['Link'][i]
    video = pafy.new(url)
    duration = np.append(duration,video.length)
    print("Index %d and length %d" %(i,video.length))
# Out:
# Index 0 and length 6
# Index 1 and length 3
# Index 2 and length 4
# Index 3 and length 3
# Index 4 and length 4
# Index 5 and length 14
# Index 6 and length 4
# Index 7 and length 4
# Index 8 and length 4
# Index 9 and length 4
# Index 10 and length 5
# Index 11 and length 4
# Index 12 and length 2
# Index 13 and length 10
# Index 14 and length 5
# Index 15 and length 6
# Index 16 and length 3
# Index 17 and length 3
# Index 18 and length 3
# Index 19 and length 5
# Index 20 and length 6
# Index 21 and length 4
# Index 22 and length 3
# Index 23 and length 3
# Index 24 and length 3
# Index 25 and length 4
# Index 26 and length 5
# Index 27 and length 5
# Index 28 and length 3
# Index 29 and length 4
# Index 30 and length 3
# Index 31 and length 5
# Index 32 and length 3
# Index 33 and length 3
# Index 34 and length 6
# Index 35 and length 3
# Index 36 and length 4
# Index 37 and length 4
# Index 38 and length 5
# Index 39 and length 4
# Index 40 and length 5
# Index 41 and length 4
# ...

# %%
df[index=1]
# Out:
#   File "<ipython-input-20-ceb8ec0842fa>", line 1
#     df[df[index=1]]
#                ^
# SyntaxError: invalid syntax
