# %%
# Trying Scraping using Beautiful Soup

# %%
# Import Required Module
import requests
from bs4 import BeautifulSoup
 
# Web URL
# Web_url = "https://www.youtube.com/channel/UCwq6l6nG1rLF7g6tJTPicFg"
Web_url = "https://indiansignlanguage.org/above/"
# Get URL Content
r = requests.get(Web_url)
 
# Parse HTML Code
soup = BeautifulSoup(r.content, 'html.parser')
 
# List of all video tag
video_tags = soup.findAll('iframe')
for video_tag in video_tags:
  video_url = video_tag['src']
  print(video_url)
# print("Total ", len(video_tags), "videos found")
 
# if len(video_tags) != 0:
#     for video_tag in video_tags:
#         video_url = video_tag.find("a")['href']
#         print(video_url)
# else:
#     print("no videos found")

# %%
# Import Required Module
import requests
from bs4 import BeautifulSoup
 
# Web URL
# Web_url = "https://www.youtube.com/channel/UCwq6l6nG1rLF7g6tJTPicFg"
Web_url = "https://indiansignlanguage.org/above/"

# Get URL Content
r = requests.get(Web_url)
 
# Parse HTML Code
soup = BeautifulSoup(r.content, 'html.parser')
 
# List of all video tag
anchor = soup.findAll('a')
print(anchor)
 
if len(video_tags) != 0:
    for video_tag in video_tags:
        video_url = video_tag.find("a")['href']
        print(video_url)
else:
    print("no videos found")

body=str(soup('body'))
print(soup.prettify())
print(soup.body.div)
li=soup.find_all(class_="letter-section")
for li2 in li:
  print(li2.get('href'))
li = BeautifulSoup(bytes(li2[0], 'utf-8'),'html5lib')
print(li)
# Out:
# [<a href="https://macinline.com/answeradenoidal.php?lang=321">table</a>, <a href="https://www.cloudflare.com/5xx-error-landing" id="brand_link" rel="noopener noreferrer" target="_blank">Cloudflare</a>]
# no videos found
# <!DOCTYPE html>
# <!--[if lt IE 7]> <html class="no-js ie6 oldie" lang="en-US"> <![endif]-->
# <!--[if IE 7]>    <html class="no-js ie7 oldie" lang="en-US"> <![endif]-->
# <!--[if IE 8]>    <html class="no-js ie8 oldie" lang="en-US"> <![endif]-->
# <!--[if gt IE 8]><!-->
# <html class="no-js" lang="en-US">
#  <!--<![endif]-->
#  <head>
#   <title>
#    Please Wait... | Cloudflare
#   </title>
#   <meta id="captcha-bypass" name="captcha-bypass"/>
#   <meta charset="utf-8"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="IE=Edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <meta content="noindex, nofollow" name="robots"/>
#   <meta content="width=device-width,initial-scale=1" name="viewport"/>
# ...

# %%
# Import Required Module
import requests
from bs4 import BeautifulSoup
 
# Web URL
# Web_url = "https://www.youtube.com/channel/UCwq6l6nG1rLF7g6tJTPicFg"
Web_url = "https://indiansignlanguage.org/above/"

# Get URL Content
r = requests.get(Web_url)
 
# Parse HTML Code
soup = BeautifulSoup(r.content, 'html.parser')
 
# List of all video tag
anchor = soup.findAll('a')
print(anchor)
 
if len(video_tags) != 0:
    for video_tag in video_tags:
        video_url = video_tag.find("a")['href']
        print(video_url)
else:
    print("no videos found")
# Out:
# [<a href="https://macinline.com/answeradenoidal.php?lang=321">table</a>, <a href="https://www.cloudflare.com/5xx-error-landing" id="brand_link" rel="noopener noreferrer" target="_blank">Cloudflare</a>]
# no videos found

# %%
# Import Required Module
import requests
from bs4 import BeautifulSoup
 
# Web URL
# Web_url = "https://www.youtube.com/channel/UCwq6l6nG1rLF7g6tJTPicFg"
Web_url = "https://indiansignlanguage.org/above/"
# Get URL Content
r = requests.get(Web_url)
 
# Parse HTML Code
soup = BeautifulSoup(r.content, 'html.parser')

iFrames=[] # qucik bs4 example
for iframe in soup("iframe"):
    iFrames.append(soup.iframe) 

print(iFrames)

for i in iFrames:
  print(i)
# Out:
# []

# %%
from bs4 import BeautifulSoup
import requests
  
# sample web page
sample_web_page =  "https://indiansignlanguage.org/above/"
  
# call get method to request that page
page = requests.get(sample_web_page)
  
# with the help of beautifulSoup and html parser create soup
soup = BeautifulSoup(page.content, "html.parser")
  
child_soup = soup.find_all('strong')
  
text = 'page table base register (PTBR)'
  
# we will search the tag with in which text is same as given text
for i in child_soup:
    if(i.string == text):
        print(i)

# %%
# Import Required Module
import requests
from bs4 import BeautifulSoup
 
# Web URL
# Web_url = "https://www.youtube.com/channel/UCwq6l6nG1rLF7g6tJTPicFg"
Web_url = "https://indiansignlanguage.org/above/"
# Get URL Content
r = requests.get(Web_url)
 
# Parse HTML Code
soup = BeautifulSoup(r.content, 'html.parser')
print(soup)

#FIND OUT THE LAST PAGE NUMBER FROM THE SOURCE CODE!!!
# Out:
# <!DOCTYPE html>
#
# <!--[if lt IE 7]> <html class="no-js ie6 oldie" lang="en-US"> <![endif]-->
# <!--[if IE 7]>    <html class="no-js ie7 oldie" lang="en-US"> <![endif]-->
# <!--[if IE 8]>    <html class="no-js ie8 oldie" lang="en-US"> <![endif]-->
# <!--[if gt IE 8]><!--> <html class="no-js" lang="en-US"> <!--<![endif]-->
# <head>
# <title>Please Wait... | Cloudflare</title>
# <meta id="captcha-bypass" name="captcha-bypass"/>
# <meta charset="utf-8"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=Edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="noindex, nofollow" name="robots"/>
# <meta content="width=device-width,initial-scale=1" name="viewport"/>
# <link href="/cdn-cgi/styles/cf.errors.css" id="cf_styles-css" media="screen,projection" rel="stylesheet" type="text/css"/>
# ...

# %% [markdown]
# https://www.youtube.com/embed/
