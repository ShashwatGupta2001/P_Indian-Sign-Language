# %%
api_key="AIzaSyBasPVwLAI1VFxN-LvXN19t9ZA5W3vX9qw"
from apiclient.discovery import build
youtube = build('youtube', 'v3', developerKey=api_key)
res = youtube.channels().list(id="UCmM7KPLEthAXiPVAgBF6rhA",part="contentDetails").execute()
res
# Out:
# {'etag': '1CpfQUGY9i2bDRfixd2Iua05Y9c',
#  'items': [{'contentDetails': {'relatedPlaylists': {'likes': '',
#      'uploads': 'UUmM7KPLEthAXiPVAgBF6rhA'}},
#    'etag': '1e2zrUD3czovMk-xck28V1YqsfU',
#    'id': 'UCmM7KPLEthAXiPVAgBF6rhA',
#    'kind': 'youtube#channel'}],
#  'kind': 'youtube#channelListResponse',
#  'pageInfo': {'resultsPerPage': 5, 'totalResults': 1}}

# %%
res=youtube.playlistItems().list(playlistId='UUmM7KPLEthAXiPVAgBF6rhA',part='snippet',maxResults=50).execute()
res
# Out:
# {'etag': 'exzJQ9VO894p2lxDf7VrUM76PWw',
#  'items': [{'etag': 'SQvGgKvLnBLA-Ngyp1Hr1ofa-jI',
#    'id': 'VVVtTTdLUExFdGhBWGlQVkFnQkY2cmhBLkNtMF9yYnBVemFv',
#    'kind': 'youtube#playlistItem',
#    'snippet': {'channelId': 'UCmM7KPLEthAXiPVAgBF6rhA',
#     'channelTitle': 'Indian Sign Language RKMVU-CBE',
#     'description': '',
#     'playlistId': 'UUmM7KPLEthAXiPVAgBF6rhA',
#     'position': 0,
#     'publishedAt': '2013-09-13T06:34:01Z',
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'Cm0_rbpUzao'},
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/Cm0_rbpUzao/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/Cm0_rbpUzao/hqdefault.jpg',
#       'width': 480},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/Cm0_rbpUzao/mqdefault.jpg',
#       'width': 320}},
#     'title': 'An Ant went to a Sugar Hill',
# ...

# %%
# we now got that total videos are 3767

# %%
def get_channel_videos(channel_id):
    res=youtube.channels().list(id=channel_id,part='contentDetails').execute()
    playlist_id=res['items'][0]['contentDetails']['relatedPlaylists']['uploads']
    videos=[]
    next_page_token=None

    while 1:
        res=youtube.playlistItems().list(playlistId=playlist_id,part='snippet',maxResults=50,pageToken=next_page_token).execute()
        videos+=res['items']
        next_page_token=res.get('nextPageToken')
        if next_page_token is None:
            break
    
    return videos

# %%
videos = get_channel_videos('UCmM7KPLEthAXiPVAgBF6rhA')

# %%
len(videos)
# Out:
# 3767

# %%
for video in videos:
  print(str(video['snippet']['title']) + ":" + str(video['snippet']['resourceId']['videoId']))
# Out:
# An Ant went to a Sugar Hill:Cm0_rbpUzao
# Thus saw Arjuna:-QKXmGJMyGg
# When All Teeth Fall:AF4MTwCKQLw
# Ka Ka Ka:epTWE7xIX5U
# Then, What's the Way:iRUB2agT2sc
# A Devotee Avoids what the World Runs after:kjkXbREqz6Q
# The Power of Faith:VMNiZjuRHZg
# The Doubting Soul Perishes:TDJCn1M4K-g
# Such is the Pride Money Begets:ED-zEbXA030
# Nature of God:FVfQt7NV73k
# A Bahurupi Impersonating Siva:GIbTWUBe0Vo
# When God Laughs:bVGZd2xY1Aw
# What You are after is within Yourself:ss0YVPrxsCQ
# Three Friends and the Tiger:fnp1oJvjR7w
# The Root of All Troubles:4sYlqViNKe8
# The Peacock that Tasted Opium:XruX_57AayQ
# The Grass eating Tiger:8jA4YWmTr4k
# The Best offering to God is Love:LhkvU6B2IYs
# Self help and Self surrender:tvhN50SZ9EE
# Hold Hard Your Spade:EhHOZpHFBI8
# Hanuman Singh and the Wrestler from the Punjab:7bZJO3FJuC4
# Go Forward!:wDeHW8v7gqo
# Give the Dog a Good Beating at Times:Yp-StLLXVG0
# Feigning Madness too is Risky!:9_Cbq8vAXeQ
# ...

# %%
import sys
# !{sys.executable} -m pip install requests
# !{sys.executable} -m pip install bs4

# %%
from bs4 import BeautifulSoup
import requests
import re
import codecs
#https://indiansignlanguage.org/
words=[]
URL = requests.get("https://indiansignlanguage.org/")
f = codecs.open("ISLorg.html",'r', encoding='utf-8')
soup = BeautifulSoup(f.read(),'html5lib')
# body=str(soup('body'))
# print(soup.prettify())
# print(soup.body.div)
li=soup.find_all('a')
count=0
for li2 in li:
  count+=1
# for li2 in li:
#   print(li2.get('href'))
# li = BeautifulSoup(bytes(li2[0], 'utf-8'),'html5lib')
print(li)
print(count)
# Out:
# [<a class="skip-link screen-reader-text" href="#content">Skip to content</a>, <a class="mega-menu-link" href="https://indiansignlanguage.org/" tabindex="0">Home</a>, <a aria-expanded="false" aria-haspopup="true" class="mega-menu-link" href="https://indiansignlanguage.org/about-us/" tabindex="0">About Us<span class="mega-indicator"></span></a>, <a class="mega-menu-link" href="https://indiansignlanguage.org/indian-sign-language/">Indian Sign Language</a>, <a class="mega-menu-link" href="https://indiansignlanguage.org/history/">History</a>, <a class="mega-menu-link" href="https://indiansignlanguage.org/what-is-the-purpose-of-this-website/">What is the Purpose of this Website?</a>, <a class="mega-menu-link" href="https://indiansignlanguage.org/audiological-evaluation/">Audiological Evaluation</a>, <a class="mega-menu-link" href="https://indiansignlanguage.org/educational-services/">Educational Services</a>, <a class="mega-menu-link" href="https://indiansignlanguage.org/courses/">Courses<
# ...

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
driver = webdriver.Firefox()
driver.get("https://indiansignlanguage.org/")
print(driver)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-6fdba316aeec> in <module>()
# ----> 1 from selenium import webdriver
#       2 from selenium.webdriver.common.keys import Keys
#       3 driver = webdriver.Firefox()
#       4 driver.get("https://indiansignlanguage.org/")
#       5 print(driver)
#
# ModuleNotFoundError: No module named 'selenium'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
